# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('datasets/percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15, 18))

degrees = [stem_cats, lib_arts_cats, other_cats]

for c_index in range(0, len(degrees)):
    courses = degrees[c_index]    
    for sp in range(0, len(courses)):
        row = sp*3 + c_index + 1

        ax = fig.add_subplot(6,3,row)
        ax.plot(women_degrees['Year'], women_degrees[courses[sp]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[courses[sp]], c=cb_orange, label='Men', linewidth=3)
        ax.spines["right"].set_visible(False)    
        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)    
        ax.spines["bottom"].set_visible(False)
        ax.set_xlim(1968, 2011)
        ax.set_ylim(0,100)
        ax.set_title(courses[sp])
        ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
        ax.set_yticks([0,100])
        ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
        
        if sp == len(courses) - 1:
            ax.tick_params(labelbottom='on')
    
        if sp == 0:
            ax.text(2005, 80, 'Men')
            ax.text(2002, 15, 'Women')
        elif sp == 5:
            ax.text(2005, 90, 'Men')
            ax.text(2001, 10, 'Women')
            
fig.savefig("images/gender_degrees.png")
plt.show()

# %%
# plt.close()
# for c_index in range(0, len(degrees)):
#     courses = degrees[c_index]    
#     for sp in range(0, len(courses)):
#         plt.plot(women_degrees['Year'], women_degrees[courses[sp]])
#         plt.savefig("images/" + courses[sp] + ".png")
#         plt.close()
